# %%
import json

with open('config.json', 'r') as f:
    config = json.load(f)

# %%
from utils.custom_treat_data_funcs import read_all_csvs_into_pandas

# %%
df_train = read_all_csvs_into_pandas(config["FPATH_TRAIN"])

# %%
df_train
# Out:
#                                                   userId    userType  \
# 0      fbb963d61eb8149e7f43b1bd905457ba5e106a830ddc27...  Non-Logged
# 1      17f1083e6079b0f28f7820a6803583d1c1b405c0718b11...  Non-Logged
# 2      528a8d7a2af73101da8d6709c1ec875b449a5a58749a99...  Non-Logged
# 3      2dd18b58a634a4e77181a202cf152df6169dfb3e4230ef...  Non-Logged
# 4      97e1439d485b0630e12818d3df84ff67d08475ef6ebeb0...      Logged
# ...                                                  ...         ...
# 30010  8122ca5035f956232eeb4a113b3ebee418143788dd6363...  Non-Logged
# 30011  23c2612213d8d0d0dc32ad0d9de1190221f3dbbbd4b325...  Non-Logged
# 30012  6bbe42bc342683a203533173cc5b764196a6647d91b619...      Logged
# 30013  934f029d08ac7cb8883c04e6d5e7f6b3f9bdda491d5225...  Non-Logged
# 30014  695970175ff28276d256f7474a916b33da0964cbdfb2d7...  Non-Logged
#
#        historySize                                            history  \
# 0                2  80aa7bb2-adce-4a55-9711-912c407927a1, d9e5f15d...
# 1                2  19ba89fc-1e06-4c5d-9c57-4a3088dc0511, e273dba4...
# 2                2  59a61a8a-cc52-453f-b1cd-2bd019e9d574, a0562805...
# 3                2  233f8238-2ce0-470f-a9d5-0e0ac530382a, 037155f4...
# 4                2  385044ad-3876-4188-83fa-f560435c1a9c, 2f754502...
# ...            ...                                                ...
# 30010            2  fcc5889d-e76c-4c03-a1cf-f8cfc32d9cd3, 07b124c1...
# 30011            2  fb0938f6-52bb-49a6-997f-29e0d91c5e9c, 1ee0f486...
# 30012            2  d8e96969-c9d9-4c28-a9a8-403abc1e784a, f932eaf7...
# 30013            2  fbbd2472-9ee2-4d84-9211-deb431ba8a75, 7c08153b...
# 30014            2  c6416d03-5045-4d6c-bc70-e134f91d99a8, 225b0c0a...
#
#                    timestampHistory numberOfClicksHistory timeOnPageHistory  \
# 0      1657908085200, 1659634203762                  0, 0     71998, 115232
# 1      1657111508570, 1657481309920                68, 12     131495, 43733
# 2      1657823890328, 1660141444328                 55, 9     159042, 10336
# 3      1656963373076, 1657091888917                  0, 0     193579, 20519
# 4      1657618607633, 1659536839832                57, 38    220000, 130000
# ...                             ...                   ...               ...
# 30010  1659306150568, 1659306765601                  1, 8      88120, 70000
# 30011  1658367235999, 1660489190183                  0, 1     20000, 120000
# 30012  1657494485763, 1660072571832                  0, 1      40000, 84246
# 30013  1658495162454, 1659550908263                  0, 0      81573, 73388
# 30014  1659692462057, 1659692626630                 23, 4       60000, 8211
#
#       scrollPercentageHistory pageVisitsCountHistory  \
# 0                81.58, 73.36                   1, 1
# 1                51.74, 35.49                   1, 1
# 2                62.19, 48.28                   1, 1
# 3                 31.03, 31.9                   1, 1
# 4                52.65, 53.37                   1, 1
# ...                       ...                    ...
# 30010            47.04, 57.84                   1, 1
# 30011             4.98, 70.04                   1, 1
# 30012            18.69, 55.06                   1, 1
# 30013            51.07, 67.88                   1, 1
# 30014             70.2, 35.43                   1, 1
#
#                timestampHistory_new
# 0      1657908085200, 1659634203762
# 1      1657111508570, 1657481309920
# 2      1657823890328, 1660141444328
# 3      1656963373076, 1657091888917
# 4      1657618607633, 1659536839832
# ...                             ...
# 30010  1659306150568, 1659306765601
# 30011  1658367235999, 1660489190183
# 30012  1657494485763, 1660072571832
# 30013  1658495162454, 1659550908263
# 30014  1659692462057, 1659692626630
#
# [30015 rows x 10 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30015 entries, 0 to 30014
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   userId                   30015 non-null  object
#  1   userType                 30015 non-null  object
#  2   historySize              30015 non-null  int64
#  3   history                  30015 non-null  object
#  4   timestampHistory         30015 non-null  object
#  5   numberOfClicksHistory    30015 non-null  object
#  6   timeOnPageHistory        30015 non-null  object
#  7   scrollPercentageHistory  30015 non-null  object
#  8   pageVisitsCountHistory   30015 non-null  object
#  9   timestampHistory_new     30015 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.3+ MB

# %%
df_train.describe()
# Out:
#         historySize
# count  30015.000000
# mean      14.271564
# std       43.638953
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        6.000000
# max     1444.000000

# %%
df_items = read_all_csvs_into_pandas(config["FPATH_ITEMS"])

# %%
df_items.describe()
# Out:
#                                         page  \
# count                                  13809
# unique                                 13809
# top     505ad718-bb1a-4cbf-a020-d5f7a4ab335f
# freq                                       1
#
#                                                       url  \
# count                                               13809
# unique                                              13809
# top     http://g1.globo.com/rn/rio-grande-do-norte/not...
# freq                                                    1
#
#                            issued                   modified  \
# count                       13809                      13809
# unique                      13805                      13803
# top     2018-10-08 20:30:23+00:00  2021-01-01 04:43:29+00:00
# freq                            2                          2
#
#                                                     title  \
# count                                               13809
# unique                                              13804
# top     Empresas abrem vagas de emprego, estágio e tra...
# freq                                                    2
#
#                                                      body  \
# count                                               13809
# unique                                              13809
# top     Isolda do Nascimento, de 56 anos, foi encontra...
# freq                                                    1
#
#                                                   caption
# count                                               13809
# unique                                              13723
# top     Veja como obter informações das empresas citad...
# freq                                                   11

# %%
cols_to_explode = ["history", "numberOfClicksHistory", "timeOnPageHistory", "scrollPercentageHistory", "pageVisitsCountHistory"]
# cols_to_explode = ["history"]
cols_and_id = cols_to_explode.copy()
cols_and_id.insert(0,"userId")
cols_and_id.append("userType")
cols_and_id = tuple(cols_and_id)
print(cols_and_id)
print(cols_to_explode)
# Out:
# ('userId', 'history', 'numberOfClicksHistory', 'timeOnPageHistory', 'scrollPercentageHistory', 'pageVisitsCountHistory', 'userType')
# ['history', 'numberOfClicksHistory', 'timeOnPageHistory', 'scrollPercentageHistory', 'pageVisitsCountHistory']

# %%
df_train.loc[:,cols_and_id]
# Out:
#                                                   userId  \
# 0      fbb963d61eb8149e7f43b1bd905457ba5e106a830ddc27...
# 1      17f1083e6079b0f28f7820a6803583d1c1b405c0718b11...
# 2      528a8d7a2af73101da8d6709c1ec875b449a5a58749a99...
# 3      2dd18b58a634a4e77181a202cf152df6169dfb3e4230ef...
# 4      97e1439d485b0630e12818d3df84ff67d08475ef6ebeb0...
# ...                                                  ...
# 30010  8122ca5035f956232eeb4a113b3ebee418143788dd6363...
# 30011  23c2612213d8d0d0dc32ad0d9de1190221f3dbbbd4b325...
# 30012  6bbe42bc342683a203533173cc5b764196a6647d91b619...
# 30013  934f029d08ac7cb8883c04e6d5e7f6b3f9bdda491d5225...
# 30014  695970175ff28276d256f7474a916b33da0964cbdfb2d7...
#
#                                                  history  \
# 0      80aa7bb2-adce-4a55-9711-912c407927a1, d9e5f15d...
# 1      19ba89fc-1e06-4c5d-9c57-4a3088dc0511, e273dba4...
# 2      59a61a8a-cc52-453f-b1cd-2bd019e9d574, a0562805...
# 3      233f8238-2ce0-470f-a9d5-0e0ac530382a, 037155f4...
# 4      385044ad-3876-4188-83fa-f560435c1a9c, 2f754502...
# ...                                                  ...
# 30010  fcc5889d-e76c-4c03-a1cf-f8cfc32d9cd3, 07b124c1...
# 30011  fb0938f6-52bb-49a6-997f-29e0d91c5e9c, 1ee0f486...
# 30012  d8e96969-c9d9-4c28-a9a8-403abc1e784a, f932eaf7...
# 30013  fbbd2472-9ee2-4d84-9211-deb431ba8a75, 7c08153b...
# 30014  c6416d03-5045-4d6c-bc70-e134f91d99a8, 225b0c0a...
#
#       numberOfClicksHistory timeOnPageHistory scrollPercentageHistory  \
# 0                      0, 0     71998, 115232            81.58, 73.36
# 1                    68, 12     131495, 43733            51.74, 35.49
# 2                     55, 9     159042, 10336            62.19, 48.28
# 3                      0, 0     193579, 20519             31.03, 31.9
# 4                    57, 38    220000, 130000            52.65, 53.37
# ...                     ...               ...                     ...
# 30010                  1, 8      88120, 70000            47.04, 57.84
# 30011                  0, 1     20000, 120000             4.98, 70.04
# 30012                  0, 1      40000, 84246            18.69, 55.06
# 30013                  0, 0      81573, 73388            51.07, 67.88
# 30014                 23, 4       60000, 8211             70.2, 35.43
#
#       pageVisitsCountHistory    userType
# 0                       1, 1  Non-Logged
# 1                       1, 1  Non-Logged
# 2                       1, 1  Non-Logged
# 3                       1, 1  Non-Logged
# 4                       1, 1      Logged
# ...                      ...         ...
# 30010                   1, 1  Non-Logged
# 30011                   1, 1  Non-Logged
# 30012                   1, 1      Logged
# 30013                   1, 1  Non-Logged
# 30014                   1, 1  Non-Logged
#
# [30015 rows x 7 columns]

# %%
from utils.custom_treat_data_funcs import explode_df_columns

exploded_df = explode_df_columns(df_train.loc[:,cols_and_id], cols_to_explode)

# %%
exploded_df
# Out:
#                                                    userId  \
# 0       fbb963d61eb8149e7f43b1bd905457ba5e106a830ddc27...
# 1       fbb963d61eb8149e7f43b1bd905457ba5e106a830ddc27...
# 2       17f1083e6079b0f28f7820a6803583d1c1b405c0718b11...
# 3       17f1083e6079b0f28f7820a6803583d1c1b405c0718b11...
# 4       528a8d7a2af73101da8d6709c1ec875b449a5a58749a99...
# ...                                                   ...
# 428356  6bbe42bc342683a203533173cc5b764196a6647d91b619...
# 428357  934f029d08ac7cb8883c04e6d5e7f6b3f9bdda491d5225...
# 428358  934f029d08ac7cb8883c04e6d5e7f6b3f9bdda491d5225...
# 428359  695970175ff28276d256f7474a916b33da0964cbdfb2d7...
# 428360  695970175ff28276d256f7474a916b33da0964cbdfb2d7...
#
#                                      history numberOfClicksHistory  \
# 0       80aa7bb2-adce-4a55-9711-912c407927a1                     0
# 1       d9e5f15d-b441-4d8b-bee4-462b106d3916                     0
# 2       19ba89fc-1e06-4c5d-9c57-4a3088dc0511                    68
# 3       e273dba4-136c-45fb-bdd6-0cc57b13aaf0                    12
# 4       59a61a8a-cc52-453f-b1cd-2bd019e9d574                    55
# ...                                      ...                   ...
# 428356  f932eaf7-d587-4461-a511-dddb26d5b0ed                     1
# 428357  fbbd2472-9ee2-4d84-9211-deb431ba8a75                     0
# 428358  7c08153b-075b-4bed-a8b3-0f6b52ab4a92                     0
# 428359  c6416d03-5045-4d6c-bc70-e134f91d99a8                    23
# 428360  225b0c0a-f72c-4a33-9ce7-88500fb4c786                     4
#
#        timeOnPageHistory scrollPercentageHistory pageVisitsCountHistory  \
# 0                  71998                   81.58                      1
# 1                 115232                   73.36                      1
# 2                 131495                   51.74                      1
# 3                  43733                   35.49                      1
# 4                 159042                   62.19                      1
# ...                  ...                     ...                    ...
# 428356             84246                   55.06                      1
# 428357             81573                   51.07                      1
# 428358             73388                   67.88                      1
# 428359             60000                    70.2                      1
# 428360              8211                   35.43                      1
#
#           userType
# 0       Non-Logged
# 1       Non-Logged
# 2       Non-Logged
# 3       Non-Logged
# 4       Non-Logged
# ...            ...
# 428356      Logged
# 428357  Non-Logged
# 428358  Non-Logged
# 428359  Non-Logged
# 428360  Non-Logged
#
# [428361 rows x 7 columns]

# %%
exploded_df.describe()
# Out:
#                                                    userId  \
# count                                              428361
# unique                                              30015
# top     18487399f7018df56613e392acfe962153618e4d2db576...
# freq                                                 1444
#
#                                      history numberOfClicksHistory  \
# count                                 428361                428361
# unique                                 56683                   492
# top     d2593c3d-2347-40d9-948c-b6065e8459a9                     0
# freq                                    1331                166667
#
#        timeOnPageHistory scrollPercentageHistory pageVisitsCountHistory  \
# count             428361                  428361                 428361
# unique            147913                    9885                     83
# top                10000                    12.5                      1
# freq               23998                   12662                 391699
#
#           userType
# count       428361
# unique           2
# top     Non-Logged
# freq        236116

# %%
from utils.custom_treat_data_funcs import check_if_exploded_df_size_is_ok

check_if_exploded_df_size_is_ok(df_train, exploded_df)
# Out:
# True

# %%
exploded_df['numberOfClicksHistory'] = exploded_df['numberOfClicksHistory'].astype('int32')
exploded_df['timeOnPageHistory'] = exploded_df['timeOnPageHistory'].astype('int64')
exploded_df['scrollPercentageHistory'] = exploded_df['scrollPercentageHistory'].astype('float32')
exploded_df['pageVisitsCountHistory'] = exploded_df['pageVisitsCountHistory'].astype('int32')

# %%
exploded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428361 entries, 0 to 428360
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   userId                   428361 non-null  object
#  1   history                  428361 non-null  object
#  2   numberOfClicksHistory    428361 non-null  int32
#  3   timeOnPageHistory        428361 non-null  int64
#  4   scrollPercentageHistory  428361 non-null  float32
#  5   pageVisitsCountHistory   428361 non-null  int32
#  6   userType                 428361 non-null  object
# dtypes: float32(1), int32(2), int64(1), object(3)
# memory usage: 18.0+ MB

# %%
exploded_df.isnull().sum()
# Out:
# userId                     0
# history                    0
# numberOfClicksHistory      0
# timeOnPageHistory          0
# scrollPercentageHistory    0
# pageVisitsCountHistory     0
# userType                   0
# dtype: int64

# %%
exploded_df.userId.nunique()
# Out:
# 30015

# %%
exploded_df.history.nunique()
# Out:
# 56683

# %%
exploded_df["history"].value_counts().head(100)
# Out:
# history
# d2593c3d-2347-40d9-948c-b6065e8459a9    1331
# f6b5d170-48b9-4f8e-88d4-c84b6668f3bd    1148
# 1f32787b-de2b-49be-8c20-ddaeae34cc22    1019
# 6a83890a-d9e9-4f6b-a6c6-90d031785bbf    1017
# f0a78e58-ec7e-494c-9462-fbd6446a9a89     960
#                                         ...
# a8f0cda0-6c9c-45f6-b72a-3c20ba9624ea     415
# 3936f6c7-3f6c-4205-8cda-3178160b6cd4     415
# 8956c97a-6d85-4d4b-a6f7-6d42c6be97cc     414
# b4a5680b-d0e1-4260-bc54-82fbe328d3a0     412
# e22473a3-7a8a-46cb-8c86-1bda7a5c70de     412
# Name: count, Length: 100, dtype: int64

# %%
exploded_df.head()
# Out:
#                                               userId  \
# 0  fbb963d61eb8149e7f43b1bd905457ba5e106a830ddc27...
# 1  fbb963d61eb8149e7f43b1bd905457ba5e106a830ddc27...
# 2  17f1083e6079b0f28f7820a6803583d1c1b405c0718b11...
# 3  17f1083e6079b0f28f7820a6803583d1c1b405c0718b11...
# 4  528a8d7a2af73101da8d6709c1ec875b449a5a58749a99...
#
#                                 history  numberOfClicksHistory  \
# 0  80aa7bb2-adce-4a55-9711-912c407927a1                      0
# 1  d9e5f15d-b441-4d8b-bee4-462b106d3916                      0
# 2  19ba89fc-1e06-4c5d-9c57-4a3088dc0511                     68
# 3  e273dba4-136c-45fb-bdd6-0cc57b13aaf0                     12
# 4  59a61a8a-cc52-453f-b1cd-2bd019e9d574                     55
#
#    timeOnPageHistory  scrollPercentageHistory  pageVisitsCountHistory  \
# 0              71998                81.580002                       1
# 1             115232                73.360001                       1
# 2             131495                51.740002                       1
# 3              43733                35.490002                       1
# 4             159042                62.189999                       1
#
#      userType
# 0  Non-Logged
# 1  Non-Logged
# 2  Non-Logged
# 3  Non-Logged
# 4  Non-Logged

# %%
exploded_df.shape
# Out:
# (428361, 7)

# %%
exploded_df.to_csv(config["TREATED_TRAIN_CSV"])

# %%
df_items.to_csv(config["TREATED_ITEMS_CSV"])
