# %% [markdown]
# # Modelo item-based
# - Métrica de avaliação: número de cliques na notícia
# - Pega mais "populares" para usuários não conhecidos

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

df_training = pd.read_csv("../data/training_data.csv")
df_news = pd.read_csv("../data/noticias.csv")

# %%
df_training = df_training.drop(columns=["Unnamed: 0"])
df_news= df_news.drop(columns=["Unnamed: 0"])

# %%
df_training.head()
# Out:
#    userId                               history  numberOfClicksHistory  \
# 0       0  c8aab885-433d-4e46-8066-479f40ba7fb2                     76
# 1       0  68d2039c-c9aa-456c-ac33-9b2e8677fba7                     38
# 2       0  13e423ce-1d69-4c78-bc18-e8c8f7271964                     41
# 3       1  3325b5a1-979a-4cb3-82b6-63905c9edbe8                      7
# 4       1  fe856057-f97d-419f-ab1c-97c5c3e0719c                     80
#
#    timeOnPageHistory  scrollPercentageHistory  pageVisitsCountHistory
# 0              20380                    50.30                       2
# 1              21184                    18.18                       1
# 2              35438                    16.46                       1
# 3               6049                    25.35                       1
# 4             210489                    45.66                       1

# %%
df_news.head()
# Out:
#                                    page  \
# 0  13db0ab1-eea2-4603-84c4-f40a876c7400
# 1  92907b73-5cd3-4184-8d8c-e206aed2bf1c
# 2  61e07f64-cddf-46f2-b50c-ea0a39c22050
# 3  30e2e6c5-554a-48ed-a35f-6c6691c8ac9b
# 4  9dff71eb-b681-40c7-ac8d-68017ac36675
#
#                                                  url  \
# 0  http://g1.globo.com/am/amazonas/noticia/2022/0...
# 1  http://g1.globo.com/pa/santarem-regiao/noticia...
# 2  http://g1.globo.com/mundo/noticia/2022/07/08/e...
# 3  http://g1.globo.com/politica/noticia/2021/09/0...
# 4  http://g1.globo.com/politica/noticia/2021/09/1...
#
#                       issued                   modified  \
# 0  2022-06-18 20:37:45+00:00  2023-04-15 00:02:08+00:00
# 1  2019-06-20 17:19:52+00:00  2023-06-16 20:19:15+00:00
# 2  2022-07-08 08:55:52+00:00  2023-04-15 04:25:39+00:00
# 3  2021-09-09 19:06:46+00:00  2023-06-07 17:44:54+00:00
# 4  2021-09-15 19:16:13+00:00  2023-06-07 17:43:39+00:00
#
#                                                title  \
# 0  Caso Bruno e Dom: 3º suspeito tem prisão tempo...
# 1  Linguajar dos santarenos é diferenciado e chei...
# 2  Ex-premiê Shinzo Abe morre após ser baleado no...
# 3  Relator no STF, Fachin vota contra marco tempo...
# 4  \nApós 2 votos, pedido de vista suspende julga...
#
#                                                 body  \
# 0  Após audiência de custódia, a Justiça do Amazo...
# 1  Vista aérea de Santarém\nÁdrio Denner/ AD Prod...
# 2  Novo vídeo mostra que assassino de Shinzo Abe ...
# 3  Relator no STF, Fachin vota contra marco tempo...
# 4  Após um pedido de vista (mais tempo para análi...
#
#                                              caption
# 0  Jeferson da Silva Lima foi escoltado por agent...
# 1  As expressões santarenas não significam apenas...
# 2  Ex-primeiro-ministro foi atingido por tiros de...
# 3  Ministro defendeu que posse indígena é diferen...
# 4  Pelo marco temporal, índios só podem reivindic...

# %%
#considerando apenas noticias com mais de 30 cliques
clicks_counts = pd.DataFrame(df_training["history"].value_counts())
rare_news = clicks_counts[df_training["history"].value_counts() <= 30].index
common_news = df_training[~df_training["history"].isin(rare_news)]

# %%
df_training.shape
# Out:
# (1426291, 6)

# %%
common_news.shape
# Out:
# (1085862, 6)

# %%
common_news.head(130)
# Out:
#      userId                               history  numberOfClicksHistory  \
# 0         0  c8aab885-433d-4e46-8066-479f40ba7fb2                     76
# 1         0  68d2039c-c9aa-456c-ac33-9b2e8677fba7                     38
# 2         0  13e423ce-1d69-4c78-bc18-e8c8f7271964                     41
# 4         1  fe856057-f97d-419f-ab1c-97c5c3e0719c                     80
# 5         1  d1da8d3f-bf30-4776-8d75-5f4e24cc134e                      2
# ..      ...                                   ...                    ...
# 184       3  39410577-0d94-4790-ac41-81362bc8c915                      1
# 185       3  5db25cd8-32e2-4502-9208-b62d0e13b015                      1
# 186       3  14a54c8d-3155-4045-83bc-ae01af95a034                      1
# 187       3  bcb7755a-5046-4bd7-81cd-8ead61a27ba7                      3
# 188       3  f0a78e58-ec7e-494c-9462-fbd6446a9a89                      0
#
#      timeOnPageHistory  scrollPercentageHistory  pageVisitsCountHistory
# 0                20380                    50.30                       2
# 1                21184                    18.18                       1
# 2                35438                    16.46                       1
# 4               210489                    45.66                       1
# 5                 8672                    35.30                       1
# ..                 ...                      ...                     ...
# 184             110000                    19.11                       1
# 185              90000                    17.84                       1
# 186             190000                    16.56                       1
# 187             140000                    14.89                       1
# 188             150000                    16.02                       1
#
# [130 rows x 6 columns]

# %%
# Combine two datasets

df_merged = pd.merge(common_news,df_news, left_on='history', right_on='page', how='left')
df_merged = df_merged.drop(columns=['page'])
df_merged.head(130)
# Out:
#      userId                               history  numberOfClicksHistory  \
# 0         0  c8aab885-433d-4e46-8066-479f40ba7fb2                     76
# 1         0  68d2039c-c9aa-456c-ac33-9b2e8677fba7                     38
# 2         0  13e423ce-1d69-4c78-bc18-e8c8f7271964                     41
# 3         1  fe856057-f97d-419f-ab1c-97c5c3e0719c                     80
# 4         1  d1da8d3f-bf30-4776-8d75-5f4e24cc134e                      2
# ..      ...                                   ...                    ...
# 125       3  39410577-0d94-4790-ac41-81362bc8c915                      1
# 126       3  5db25cd8-32e2-4502-9208-b62d0e13b015                      1
# 127       3  14a54c8d-3155-4045-83bc-ae01af95a034                      1
# 128       3  bcb7755a-5046-4bd7-81cd-8ead61a27ba7                      3
# 129       3  f0a78e58-ec7e-494c-9462-fbd6446a9a89                      0
#
#      timeOnPageHistory  scrollPercentageHistory  pageVisitsCountHistory  \
# 0                20380                    50.30                       2
# 1                21184                    18.18                       1
# 2                35438                    16.46                       1
# 3               210489                    45.66                       1
# 4                 8672                    35.30                       1
# ..                 ...                      ...                     ...
# 125             110000                    19.11                       1
# 126              90000                    17.84                       1
# 127             190000                    16.56                       1
# 128             140000                    14.89                       1
# 129             150000                    16.02                       1
#
#                                                    url  \
# 0    http://g1.globo.com/sc/santa-catarina/noticia/...
# 1    http://g1.globo.com/rj/rio-de-janeiro/noticia/...
# 2    http://g1.globo.com/sc/santa-catarina/noticia/...
# 3    http://g1.globo.com/sp/itapetininga-regiao/not...
# 4    http://g1.globo.com/sp/itapetininga-regiao/not...
# ..                                                 ...
# 125  http://g1.globo.com/df/distrito-federal/notici...
# 126  http://g1.globo.com/sp/sao-paulo/noticia/2022/...
# 127  http://g1.globo.com/sp/santos-regiao/noticia/2...
# 128  http://g1.globo.com/tecnologia/noticia/2022/08...
# 129  http://g1.globo.com/mg/minas-gerais/noticia/20...
#
#                         issued                   modified  \
# 0    2022-03-19 21:03:21+00:00  2022-03-19 21:03:21+00:00
# 1    2021-11-01 03:01:20+00:00  2021-11-01 13:20:44+00:00
# 2    2022-02-01 18:33:21+00:00  2022-02-04 20:23:50+00:00
# 3    2022-08-14 11:39:11+00:00  2022-08-15 15:18:15+00:00
# 4    2022-08-13 15:26:35+00:00  2022-08-13 15:26:38+00:00
# ..                         ...                        ...
# 125  2022-08-05 10:52:35+00:00  2022-08-06 13:23:32+00:00
# 126  2022-08-05 11:26:46+00:00  2022-08-05 13:37:43+00:00
# 127  2022-08-04 08:04:59+00:00  2022-08-04 17:39:48+00:00
# 128  2022-08-04 03:01:35+00:00  2022-08-04 17:24:13+00:00
# 129  2022-08-03 20:08:46+00:00  2022-08-04 19:47:15+00:00
#
#                                                  title  \
# 0    Você viu? 'Musa das Estradas' faz vídeo de pé,...
# 1    'Mulher-Gato' foi proibida de entrar na Maré a...
# 2    Caminhoneira 'Musa das Estradas' mostra rosto ...
# 3    Designer de sobrancelhas viraliza na web ao fa...
# 4    Lancha se desprende de carro e atinge furgão e...
# ..                                                 ...
# 125  Empresário atropela e mata motociclista e deix...
# 126  Integrante do 'Sexteto', Derico chora e lament...
# 127  Bandidos escapam pelo telhado com dinheiro apó...
# 128  Faixa principal do 5G é ativada em São Paulo e...
# 129  Caso Bárbara: suspeito de envolvimento no assa...
#
#                                                   body  \
# 0    Caminhoneira Aline Füchter em pé em casa\nRepr...
# 1    Polícia Civil do Rio prende Mulher-Gato, apont...
# 2    Caminhoneira 'Musa das Estradas' mostra rosto ...
# 3    Designer de sobrancelhas viraliza na web ao fa...
# 4    Lancha se desprende de carro e atinge furgão e...
# ..                                                 ...
# 125  Empresário atropela e mata motociclista e deix...
# 126  Derico Sciotti, saxofonista na banda do Progra...
# 127  Assaltantes de banco são capturados após perse...
# 128  Sinal do 5G foi liberado nesta sexta-feira (29...
# 129  Vídeo mostra a menina Bárbara Victória sendo a...
#
#                                                caption
# 0    Caminhoneira Aline Füchter ficou em pé em fren...
# 1    Luana Rabello, segundo a polícia, é muito famo...
# 2    Aline Füchter chegou a Tubarão, onde mora, no ...
# 3    Vídeo publicado por Geizielle Ferreira Mendes,...
# 4    Batida aconteceu na Rodovia João Melão (SP-255...
# ..                                                 ...
# 125  Uma das motos foi partida ao meio; homem de 52...
# 126  Derico Sciotti trabalhou com Jô Soares durante...
# 127  Criminosos foram perseguidos pelos policiais m...
# 128  Começa a ser ofertado o 5G Standalone ou SA, q...
# 129  Causa da morte é apurada. Menina de 10 anos, q...
#
# [130 rows x 12 columns]

# %%
df_merged.shape
# Out:
# (1085862, 12)

# %%
common_news["history"].value_counts().head(100000)
# Out:
# history
# d2593c3d-2347-40d9-948c-b6065e8459a9    4282
# f6b5d170-48b9-4f8e-88d4-c84b6668f3bd    3873
# 1f32787b-de2b-49be-8c20-ddaeae34cc22    3395
# f0a78e58-ec7e-494c-9462-fbd6446a9a89    3192
# 6a83890a-d9e9-4f6b-a6c6-90d031785bbf    3121
#                                         ...
# 4da21b81-a5bd-4eb7-8c79-e168d779c523      31
# aa5f3369-168f-45e7-b005-3b9a3bfcf62f      31
# 879a2b89-1bbb-4799-a422-77f1959cacf8      31
# 3a5b4ef3-e295-409c-baca-e4f06e7f3a54      31
# 383caa1c-2040-4437-8cfd-0ea8d04c489f      31
# Name: count, Length: 5077, dtype: int64

# %%
matriz_usuarios_noticias = common_news.pivot(index='userId', columns='history', values='numberOfClicksHistory')

# %%
matriz_usuarios_noticias.head()
# Out:
# history  000e18cd-4bd3-4629-b6fa-cc7c2173acf9  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  0010fb40-55c2-480e-bd42-6cce10bdf90a  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  001b9bec-b1e2-4df2-9c43-8135627ce4c1  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  003f8e2c-a9a7-4ef9-8bee-51011e11a619  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  005063cf-ad1c-4a4d-bc96-fb6b4298ec3e  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  005a743a-0a81-4dd4-ba1f-6dc63cc33a34  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  00630ea8-4698-4748-9ef6-7c99f545a916  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  008d7a48-0864-4202-9a4e-b5d4f3c08e8b  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  008d8f56-7105-426d-bb81-7aab44b3aee6  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  00a31551-a3c4-4586-a5be-4766486583ed  ...  \
# userId                                         ...
# 0                                         NaN  ...
# 1                                         NaN  ...
# 2                                         NaN  ...
# 3                                         NaN  ...
# 4                                         NaN  ...
#
# history  ff6e7987-c84d-4147-8de1-e8acf8a93df7  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  ff7421ee-fc6f-4c5d-846a-1143fae40832  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  ff872490-bef6-4c14-b5ec-66ac9d24ad19  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  ffabc550-b315-4070-94b6-713712da8ec2  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  ffb8b407-8dbb-40d8-8ea1-d5e9aa14a690  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  ffcba96d-e286-43f0-b3cf-f2c05b0bea64  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  ffdb1505-f686-4ba6-a0a9-89d7246722f0  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  ffe56be2-f822-44ac-b7c2-6bef6e8833a6  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  ffeea3a6-d969-4a9a-baf0-101da68da3f9  \
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# history  fff8f4aa-531e-4858-9108-31ec3c0f6ee6
# userId
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# [5 rows x 5077 columns]

# %%
matriz_usuarios_noticias.loc[2,'0b5caeed-ff6f-4b9d-8375-9ad25827a4ae']
# Out:
# np.float64(1.0)

# %%
matriz_usuarios_noticias.loc[3, :].sample(10)
# Out:
# history
# 36bbc315-f866-4b25-bdd0-daa8724a6037   NaN
# ebe929f9-cb63-45cf-9b75-969a7fbf9ed3   NaN
# f3a1a5ac-ef7b-43b0-a079-9212460e90b5   NaN
# a9d44e59-4fba-44c5-9d52-c9733e81a3ec   NaN
# d1706155-a428-4cbc-88d8-c1d59d998c74   NaN
# 6d6bb0f0-0586-40ee-8db7-f7054e370707   NaN
# ab22e5cd-715a-46f0-99d8-613b981f202c   NaN
# b894ddc9-38f5-4d48-82e5-294c23eba97c   NaN
# fe9e9751-34c2-4eca-8ab0-7b66b4176a95   NaN
# a80614bb-c02c-4837-96ff-cb9239189dcd   NaN
# Name: 3, dtype: float64

# %%
def recommend(random_user,df_news,df_merged,matriz_usuarios_noticias,n_recomm=5):

    random_user_new = df_merged[(df_merged["userId"] == random_user) & (df_merged["numberOfClicksHistory"] >= 1)].sort_values(by="modified", ascending=False).reset_index()

    first_new = random_user_new["history"][0]

    new_item = matriz_usuarios_noticias[first_new]
    prediction = matriz_usuarios_noticias.corrwith(new_item).sort_values(ascending=False)
    prediction = prediction.to_frame()
    recommended = prediction.head(n_recomm)
    recommended = pd.merge(recommended,df_news, left_on='history', right_on='page', how='left')
    recommended_formated = recommended.drop(columns=[0,'page'])
    
    return recommended_formated.head(n_recomm)

# %%
random_user = int(pd.Series(df_training.userId).sample(1, random_state=45).values)
N_RECOMMENDATIONS = 5

try:
    #faz recomendação baseado em similaridade com outros usuarios
    recommends = recommend(211, df_news, df_merged, matriz_usuarios_noticias, n_recomm=N_RECOMMENDATIONS)
except:
    #recomenda mais populares caso usuário não exista
    recommends = common_news["history"].value_counts().head(5)
    recommends = pd.merge(recommends,df_news, left_on='history', right_on='page', how='left')
    recommends = recommends.drop(columns=['page']) 

recommends
# Out:
#                                                  url  \
# 0  http://g1.globo.com/saude/noticia/2022/07/01/o...
# 1  http://g1.globo.com/mundo/noticia/2022/07/24/z...
# 2  http://g1.globo.com/ce/ceara/noticia/2022/07/2...
# 3  http://g1.globo.com/mg/triangulo-mineiro/notic...
# 4  http://g1.globo.com/mundo/noticia/2022/07/09/o...
#
#                       issued                   modified  \
# 0  2022-07-01 19:46:13+00:00  2022-07-01 20:04:02+00:00
# 1  2022-07-25 01:05:07+00:00  2022-07-25 01:34:07+00:00
# 2  2022-07-26 09:35:10+00:00  2022-07-26 09:57:15+00:00
# 3  2022-07-13 11:54:52+00:00  2022-07-14 00:05:31+00:00
# 4  2022-07-09 14:42:39+00:00  2022-07-09 14:42:40+00:00
#
#                                                title  \
# 0  OMS pede ação urgente contra varíola dos macac...
# 1  Zelensky critica neutralidade brasileira: 'Se ...
# 2  Adolescente é morto a tiros pela PM quando saí...
# 3  Mulher é morta pelo marido em MG; vídeo mostra...
# 4     O delirante e fascinante mundo dos micropaíses
#
#                                                 body  \
# 0  Varíola dos macacos é semelhante à varíola que...
# 1  Zelensky fala sobre relação com Putin: 'Nem pr...
# 2  Jovem é morto em abordagem policial quando saí...
# 3  Suspeito de feminicídio foge após o crime em U...
# 4  Esta é a sede do governo de Atlantium\nDivulga...
#
#                                              caption
# 0  Em apenas duas semanas, casos da doença tripli...
# 1  Presidente da Ucrânia deu uma entrevista à Glo...
# 2  Paulo Vitor Oliveira estava em uma esquina con...
# 3  Wellen Kássia Cardoso de Melo foi morta com 5 ...
# 4  Uma micronação não é um país real por definiçã...

# %% [markdown]
# ### Colocando modelo na classe

# %%
class CustomModel():

    def __init__(self,random_user,df_news,df_merged,matriz_usuarios_noticias):
        self.random_user = random_user
        self.df_news = df_news
        self.df_merged = df_merged
        self.matriz_usuarios_noticias = matriz_usuarios_noticias

    def recommend(self,n_recomm=5):

        random_user_new = self.df_merged[(self.df_merged["userId"] == self.random_user) & (self.df_merged["numberOfClicksHistory"] >= 1)].sort_values(by="modified", ascending=False).reset_index()

        first_new = random_user_new["history"][0]

        new_item = self.matriz_usuarios_noticias[first_new]
        prediction = self.matriz_usuarios_noticias.corrwith(new_item).sort_values(ascending=False)
        prediction = prediction.to_frame()
        recommended = prediction.head(n_recomm)
        recommended = pd.merge(recommended,self.df_news, left_on='history', right_on='page', how='left')
        recommended_formated = recommended.drop(columns=[0,'page'])

        return recommended_formated.head(n_recomm)
    
    def predict(self):
        try:
            #faz recomendação baseado em similaridade com outros usuarios
            recommends = self.recommend()
        except:
            #recomenda mais populares caso usuário não exista
            recommends = common_news["history"].value_counts().head(5)
            recommends = pd.merge(recommends,df_news, left_on='history', right_on='page', how='left')
            recommends = recommends.drop(columns=['page']) 

            return recommends

        return recommends

# %%
user_id = 211
model = CustomModel(user_id, df_news, df_merged, matriz_usuarios_noticias)
result = model.predict()
result
# Out:
#                                                  url  \
# 0  http://g1.globo.com/saude/noticia/2022/07/01/o...
# 1  http://g1.globo.com/mundo/noticia/2022/07/24/z...
# 2  http://g1.globo.com/ce/ceara/noticia/2022/07/2...
# 3  http://g1.globo.com/mg/triangulo-mineiro/notic...
# 4  http://g1.globo.com/mundo/noticia/2022/07/09/o...
#
#                       issued                   modified  \
# 0  2022-07-01 19:46:13+00:00  2022-07-01 20:04:02+00:00
# 1  2022-07-25 01:05:07+00:00  2022-07-25 01:34:07+00:00
# 2  2022-07-26 09:35:10+00:00  2022-07-26 09:57:15+00:00
# 3  2022-07-13 11:54:52+00:00  2022-07-14 00:05:31+00:00
# 4  2022-07-09 14:42:39+00:00  2022-07-09 14:42:40+00:00
#
#                                                title  \
# 0  OMS pede ação urgente contra varíola dos macac...
# 1  Zelensky critica neutralidade brasileira: 'Se ...
# 2  Adolescente é morto a tiros pela PM quando saí...
# 3  Mulher é morta pelo marido em MG; vídeo mostra...
# 4     O delirante e fascinante mundo dos micropaíses
#
#                                                 body  \
# 0  Varíola dos macacos é semelhante à varíola que...
# 1  Zelensky fala sobre relação com Putin: 'Nem pr...
# 2  Jovem é morto em abordagem policial quando saí...
# 3  Suspeito de feminicídio foge após o crime em U...
# 4  Esta é a sede do governo de Atlantium\nDivulga...
#
#                                              caption
# 0  Em apenas duas semanas, casos da doença tripli...
# 1  Presidente da Ucrânia deu uma entrevista à Glo...
# 2  Paulo Vitor Oliveira estava em uma esquina con...
# 3  Wellen Kássia Cardoso de Melo foi morta com 5 ...
# 4  Uma micronação não é um país real por definiçã...
