# %% [markdown]
# ### Overview

# %% [markdown]
# ![4_predict](../docs/nbs/Model_Training-training_4.jpg)

# %% [markdown]
# # Model recommendation with lighfm

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import json
import dask.dataframe as dd

from utils.custom_treat_data_funcs import transform_text_to_list, explode_df_columns

# %% [markdown]
# ### Loading Path Infos from Config (JSON) File

# %%
with open('config.json', 'r') as f:
    config = json.load(f)

# %% [markdown]
# ### Loading Custom Functions and Artifactos for Model

# %%
import pickle
from utils.custom_data_structs import UserItemData

# from utils.model_funcs import get_user_item_data
from utils.model_funcs import recommend_by_model_scores
from utils.model_funcs import read_popular_dict_into_list, read_random_dict_into_list
from utils.model_funcs import list_intersection

loaded_user_item_data:UserItemData = pickle.load(open('artifacts/user_item_data.pkl', 'rb'))

loaded_model = pickle.load(open('artifacts/lightfm_model.pkl', 'rb'))
loaded_dict_popular_histories = pickle.load(open('artifacts/dict_popular_histories.pkl', 'rb'))
loaded_dict_random_histories = pickle.load(open('artifacts/dict_random_histories.pkl', 'rb'))

# %% [markdown]
# ### Defining some parameters and dtypes

# %%
dtype_df_valid = {
"userId" : 'string',
"userType" : 'category',
"history" : 'string',
"timestampHistory" : 'string'
}

dtype_df_train_score = {
"userId" : 'string',
"userType" : 'category',
"history" : 'string',
"score" : 'Float32',
"historyFreshnessNormalized" : 'Float32'
}

LIMIT_N_ROWS = 10000
N_PARTS_DASK = 3

# %% [markdown]
# ## READ DATA

# %% [markdown]
# ### Retrieve Validation Data (df_valid)

# %%
df_valid = pd.read_csv(config["VALID_DF"],dtype=dtype_df_valid)
# df_valid = pd.read_csv(config["VALID_DF"],dtype=dtype_df_valid,nrows=LIMIT_N_ROWS)
df_valid.dropna()
# Out:
#                                                    userId    userType  \
# 0       e25fbee3a42d45a2914f9b061df3386b2ded2d8cc1f3d4...      Logged
# 1       d0afad7ea843d86597d822f0df1d39d31a3fea7c39fdee...      Logged
# 2       755062dd39a48809880cf363b04268c3af2c003088cde0...      Logged
# 3       ec1639851d99586c7f4da928deb49187303aec6e3b8d66...      Logged
# 4       a120515626fe5d12b22b7d5a7c5008912cc69284aa26cc...      Logged
# ...                                                   ...         ...
# 112179  aacb28d7d2a4ea745e12ceba1f9ffa0c7b92aae9304ce5...  Non-Logged
# 112180  91b3a960562e34504022dbe552c0e8947af20fd14ce861...  Non-Logged
# 112181  9de95a8cd681cd21cc9a7e830859e468b83c051c11f0c4...  Non-Logged
# 112182  001455437b3ca991b144afd8cb785f7727eb0c154faa54...  Non-Logged
# 112183  c53ce611cd840e9764ddfe55e5ae88620bba9655cc9712...  Non-Logged
#
#                                                   history  \
# 0       ['be89a7da-d9fa-49d4-9fdc-388c27a15bc8'
#  '01c5...
# 1                ['77901133-aee7-4f7b-afc0-652231d76fe9']
# 2                ['857aa90f-a7ec-410d-ba82-dfa4f85d4e71']
# 3       ['b7b90e18-7613-4ca0-a8fc-fd69addfcd85'
#  '835f...
# 4       ['9c764c3a-f9f8-4fb2-b2c4-6331eaeb3dd6'
#  'b8eb...
# ...                                                   ...
# 112179           ['ecb1f348-cd55-47f7-99f9-bb2c84e93f96']
# 112180           ['ecb1f348-cd55-47f7-99f9-bb2c84e93f96']
# 112181           ['3d52cd6b-706e-49f0-9215-0340010a9845']
# 112182           ['d730c4a6-e8f6-4fde-b73a-afbe148479cd']
# 112183           ['f2cece80-1542-4fae-b4f5-12b539b19ba1']
#
#                                          timestampHistory
# 0                           [1660533136590 1660672113513]
# 1                                         [1660556860253]
# 2                                         [1660561649242]
# 3       [1660533830245 1660540831707 1660542659111 166...
# 4             [1660548813953 1660572329731 1660594848200]
# ...                                                   ...
# 112179                                    [1660546612592]
# 112180                                    [1660597026440]
# 112181                                    [1660678862844]
# 112182                                    [1660584228926]
# 112183                                    [1660584984182]
#
# [112184 rows x 4 columns]

# %% [markdown]
# ### Retrieve "Items" data (df_news)
# Contains all metadata related to the history itself
# Important:
# * "page" column is equal to "history" column on df_valid

# %%
df_news = pd.read_csv(config["DF_ITEMS_FEATURE"])
df_news.drop(columns=["Unnamed: 0"],inplace=True)
df_news.head(3)
# Out:
#                                    page  age_exp_normalized ageCategories
# 0  7371a9b5-5824-4c57-8704-00a74feebe79            0.151439      very-old
# 1  7a5ea08f-4583-49e2-ba52-a71999443f7b            0.140788      very-old
# 2  6afc8bbb-4f36-43d5-8a44-a2917df5621a            0.122610      very-old

# %% [markdown]
# ## DATA TREATMENTS

# %% [markdown]
# ### Explode validation data on "History" (and "timestampHistory") - for further Popularity
# Creates an "exploded_df" that will be used to check the "popularity" of a given history/item/page

# %%
cols_to_explode = ["history", "timestampHistory"]
cols_and_id = cols_to_explode.copy()
cols_and_id.insert(0,"userId")
cols_and_id.append("userType")
cols_and_id = tuple(cols_and_id)
exploded_df = explode_df_columns(df_valid.loc[:,cols_and_id], cols_to_explode)

# %%
df_valid
# Out:
#                                                    userId    userType  \
# 0       e25fbee3a42d45a2914f9b061df3386b2ded2d8cc1f3d4...      Logged
# 1       d0afad7ea843d86597d822f0df1d39d31a3fea7c39fdee...      Logged
# 2       755062dd39a48809880cf363b04268c3af2c003088cde0...      Logged
# 3       ec1639851d99586c7f4da928deb49187303aec6e3b8d66...      Logged
# 4       a120515626fe5d12b22b7d5a7c5008912cc69284aa26cc...      Logged
# ...                                                   ...         ...
# 112179  aacb28d7d2a4ea745e12ceba1f9ffa0c7b92aae9304ce5...  Non-Logged
# 112180  91b3a960562e34504022dbe552c0e8947af20fd14ce861...  Non-Logged
# 112181  9de95a8cd681cd21cc9a7e830859e468b83c051c11f0c4...  Non-Logged
# 112182  001455437b3ca991b144afd8cb785f7727eb0c154faa54...  Non-Logged
# 112183  c53ce611cd840e9764ddfe55e5ae88620bba9655cc9712...  Non-Logged
#
#                                                   history  \
# 0       ['be89a7da-d9fa-49d4-9fdc-388c27a15bc8'
#  '01c5...
# 1                ['77901133-aee7-4f7b-afc0-652231d76fe9']
# 2                ['857aa90f-a7ec-410d-ba82-dfa4f85d4e71']
# 3       ['b7b90e18-7613-4ca0-a8fc-fd69addfcd85'
#  '835f...
# 4       ['9c764c3a-f9f8-4fb2-b2c4-6331eaeb3dd6'
#  'b8eb...
# ...                                                   ...
# 112179           ['ecb1f348-cd55-47f7-99f9-bb2c84e93f96']
# 112180           ['ecb1f348-cd55-47f7-99f9-bb2c84e93f96']
# 112181           ['3d52cd6b-706e-49f0-9215-0340010a9845']
# 112182           ['d730c4a6-e8f6-4fde-b73a-afbe148479cd']
# 112183           ['f2cece80-1542-4fae-b4f5-12b539b19ba1']
#
#                                          timestampHistory
# 0                           [1660533136590 1660672113513]
# 1                                         [1660556860253]
# 2                                         [1660561649242]
# 3       [1660533830245 1660540831707 1660542659111 166...
# 4             [1660548813953 1660572329731 1660594848200]
# ...                                                   ...
# 112179                                    [1660546612592]
# 112180                                    [1660597026440]
# 112181                                    [1660678862844]
# 112182                                    [1660584228926]
# 112183                                    [1660584984182]
#
# [112184 rows x 4 columns]

# %%
exploded_df
# Out:
#                                                    userId  \
# 0       e25fbee3a42d45a2914f9b061df3386b2ded2d8cc1f3d4...
# 1       e25fbee3a42d45a2914f9b061df3386b2ded2d8cc1f3d4...
# 2       d0afad7ea843d86597d822f0df1d39d31a3fea7c39fdee...
# 3       755062dd39a48809880cf363b04268c3af2c003088cde0...
# 4       ec1639851d99586c7f4da928deb49187303aec6e3b8d66...
# ...                                                   ...
# 178863  aacb28d7d2a4ea745e12ceba1f9ffa0c7b92aae9304ce5...
# 178864  91b3a960562e34504022dbe552c0e8947af20fd14ce861...
# 178865  9de95a8cd681cd21cc9a7e830859e468b83c051c11f0c4...
# 178866  001455437b3ca991b144afd8cb785f7727eb0c154faa54...
# 178867  c53ce611cd840e9764ddfe55e5ae88620bba9655cc9712...
#
#                                      history timestampHistory    userType
# 0       be89a7da-d9fa-49d4-9fdc-388c27a15bc8    1660533136590      Logged
# 1       01c59ff6-fb82-4258-918f-2910cb2d4c52    1660672113513      Logged
# 2       77901133-aee7-4f7b-afc0-652231d76fe9    1660556860253      Logged
# 3       857aa90f-a7ec-410d-ba82-dfa4f85d4e71    1660561649242      Logged
# 4       b7b90e18-7613-4ca0-a8fc-fd69addfcd85    1660533830245      Logged
# ...                                      ...              ...         ...
# 178863  ecb1f348-cd55-47f7-99f9-bb2c84e93f96    1660546612592  Non-Logged
# 178864  ecb1f348-cd55-47f7-99f9-bb2c84e93f96    1660597026440  Non-Logged
# 178865  3d52cd6b-706e-49f0-9215-0340010a9845    1660678862844  Non-Logged
# 178866  d730c4a6-e8f6-4fde-b73a-afbe148479cd    1660584228926  Non-Logged
# 178867  f2cece80-1542-4fae-b4f5-12b539b19ba1    1660584984182  Non-Logged
#
# [178868 rows x 4 columns]

# %% [markdown]
# ### Checking for non-compliant "history" values
# * history should have a hash format, with 8d-4d-4d-4d-12d = 32d (column "check_size" does this check)
# * every character should be a letter in [a-f] or a number in [0-9] (column "check_chars" does this check)
# * This results in 4 hifens and 5 groups of chars (column "check_hifens" does this check)
# * example of "good" hash: a1b2c3d4-a1b2-c1d2-e1f2-a111b222c333d000
# * example of "bad" data: an url not hashed, such as https://globo.com.... (those will be removed)
# * finally, column "check_history" verifies all those aforementioned points

# %% [markdown]
# ### Remove trash and unused data
# Removing "bad" data in "history" from above checks, and also removing unused columns for this "exploded_df_valid" purpose

# %%
from utils.custom_treat_data_funcs import history_check_hash_format

exploded_df["check_history"] = exploded_df["history"].apply(history_check_hash_format)
print(exploded_df["check_history"].value_counts())
exploded_df_valid = exploded_df[~exploded_df["check_history"]==False][["userId","userType","history"]]
exploded_df_valid
# Out:
# check_history
# True     172442
# False      6426
# Name: count, dtype: int64
#                                                    userId    userType  \
# 0       e25fbee3a42d45a2914f9b061df3386b2ded2d8cc1f3d4...      Logged
# 1       e25fbee3a42d45a2914f9b061df3386b2ded2d8cc1f3d4...      Logged
# 2       d0afad7ea843d86597d822f0df1d39d31a3fea7c39fdee...      Logged
# 3       755062dd39a48809880cf363b04268c3af2c003088cde0...      Logged
# 4       ec1639851d99586c7f4da928deb49187303aec6e3b8d66...      Logged
# ...                                                   ...         ...
# 178863  aacb28d7d2a4ea745e12ceba1f9ffa0c7b92aae9304ce5...  Non-Logged
# 178864  91b3a960562e34504022dbe552c0e8947af20fd14ce861...  Non-Logged
# 178865  9de95a8cd681cd21cc9a7e830859e468b83c051c11f0c4...  Non-Logged
# 178866  001455437b3ca991b144afd8cb785f7727eb0c154faa54...  Non-Logged
# 178867  c53ce611cd840e9764ddfe55e5ae88620bba9655cc9712...  Non-Logged
#
#                                      history
# 0       be89a7da-d9fa-49d4-9fdc-388c27a15bc8
# 1       01c59ff6-fb82-4258-918f-2910cb2d4c52
# 2       77901133-aee7-4f7b-afc0-652231d76fe9
# 3       857aa90f-a7ec-410d-ba82-dfa4f85d4e71
# 4       b7b90e18-7613-4ca0-a8fc-fd69addfcd85
# ...                                      ...
# 178863  ecb1f348-cd55-47f7-99f9-bb2c84e93f96
# 178864  ecb1f348-cd55-47f7-99f9-bb2c84e93f96
# 178865  3d52cd6b-706e-49f0-9215-0340010a9845
# 178866  d730c4a6-e8f6-4fde-b73a-afbe148479cd
# 178867  f2cece80-1542-4fae-b4f5-12b539b19ba1
#
# [172442 rows x 3 columns]

# %% [markdown]
# ### Retrieve a Compact representation of df_valid, without "trash" data on "history"

# %%
df_valid = exploded_df_valid.groupby(["userId","userType"]).history.unique().to_frame().reset_index()
df_valid.dropna(inplace=True)
# Out:
# /tmp/ipykernel_188166/1906139176.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_valid = exploded_df_valid.groupby(["userId","userType"]).history.unique().to_frame().reset_index()

# %% [markdown]
# ## START RECOMMENDATIONS

# %% [markdown]
# ## Get most popular items from the "exploded_df_valid"

# %%
top_k_popular = read_popular_dict_into_list(loaded_dict_popular_histories["history"])
print(top_k_popular)
# Out:
# ['d2593c3d-2347-40d9-948c-b6065e8459a9', 'f6b5d170-48b9-4f8e-88d4-c84b6668f3bd', '1f32787b-de2b-49be-8c20-ddaeae34cc22', '6a83890a-d9e9-4f6b-a6c6-90d031785bbf', 'f0a78e58-ec7e-494c-9462-fbd6446a9a89', '4c63d7cd-4902-4ffb-9b94-578b1b2151f0', '855d20b7-53f2-4678-a10f-55402d085018']

# %% [markdown]
# ## Exemple on how to use "recommend_by_weighted_random" function
# This is used to add a "random" factor to the recommendation, thus, adding an "exploration phase" to the algorithm.
# * This "guided random" recommendation shows potential unusual items to the user
# * `df_count_histories`: store the df once, so it can be reused for each user later
# * `df_unpopular_histories`: composed by all "history" values not on `top_k_popular`
# * `unpopular_weights`: most popular histories have more chance to be selected.

# %%
random_k_histories = read_random_dict_into_list(loaded_dict_random_histories["history"])
print(random_k_histories)
# Out:
# ['6b9af32b-d168-4acd-a6e3-99665e6ee0c2', 'f82ac580-aa0c-4165-a357-27e12cb4f3cf', 'a9d50956-b9dd-475c-a3d5-20b141c3fcd8', 'd755b265-ef3a-4977-80a4-b75ab44944a0', '9410dadd-0d3b-43de-9186-e934a3da6be3', '1c663751-20d8-4764-bcee-25bbe1a5b287']

# %% [markdown]
# ## Get Recommendation from LightFM model to all Users

# %%
ddf_valid = dd.from_pandas(df_valid, npartitions=N_PARTS_DASK)

result_temp = ddf_valid.apply(lambda x :
    recommend_by_model_scores(
        x.userId,
        loaded_user_item_data,
        loaded_model),
        axis=1,
        meta=('string','string')).compute()

df_valid["recommendedByModel"] = result_temp
# Out:
# try
# 239557
# [42.002617   0.8389786 -8.834183  ... -3.3290431 -4.1762676  2.484836 ]

# %% [markdown]
# ## Get Recommendation from "recommend_by_weighted_random" to all Users

# %%
df_valid["recommendedByRandomW"] = df_valid["history"].apply(lambda x :
            read_random_dict_into_list(loaded_dict_random_histories["history"]))

# %% [markdown]
# ## Get Most Popular Recommendations to all Users
# * This one does not depends on the user
# * Can be obtained once (stored in `top_k_popular`) and just replicated to all dataset
# * Firstly, transformed into string to write to all cells
# * Secondly, transformed back to list

# %%
df_valid["recommendedByPopular"] = str(top_k_popular)
df_valid["recommendedByPopular"] = df_valid["recommendedByPopular"].apply(transform_text_to_list)

# %% [markdown]
# ## Full Recommendation List
# Composed in parts by
# 1. Items recommended by the LightFM model (good for known user/items - warm start)
# 2. Items recommended based on popularity (good for unknown users - cold start)
# 3. Items recommended randomly (good for unknown users - cold start)
# * `N_RECOMMENDS = K_LIGHTFM_ITEMS + K_POPULAR_ITEMS + K_SAMPLED_ITEMS`

# %%
df_valid["recommendedMerged"] = df_valid["recommendedByRandomW"] + df_valid["recommendedByPopular"] + df_valid["recommendedByModel"]

# %%
df_valid
# Out:
#                                                    userId    userType  \
# 1       00025217b55f104ede326550e7b46c3969a5a5333fcd29...  Non-Logged
# 2       0003f534fe8124d98eef78b01baa3b69e3ffcda6e5a657...      Logged
# 4       00043e84a871699b666933c3ca7989598879d47b325901...      Logged
# 7       0004749749d85d78d13c6c9113130278a18f069f71ccca...  Non-Logged
# 8       0004e1ddec9a5d67faa56bb734d733628a7841c10c7255...      Logged
# ...                                                   ...         ...
# 217477  fffcb5799256bd50b519b5688f54a6021ca3ef1af66b8b...  Non-Logged
# 217478  fffd676b5b33c111de923c2ce93f767f206bf7218d43a6...      Logged
# 217480  fffdf305577419378c3be19c54c443fd2744e0f2dc65dc...      Logged
# 217482  fffe0be2e6d6f38ae63123c674646bc8e759578305ae97...      Logged
# 217484  fffef1890d6f8c974caa19bb8fb46b3b4cb5dc9dc006bc...      Logged
#
#                                        history  \
# 1       [d88f5d3a-8657-4955-88fb-71702d92909a]
# 2       [6813846e-9f28-4238-8ea5-4e3436064657]
# 4       [aeab0e46-f1e4-41e9-821b-571255c41f69]
# 7       [487330a8-b48e-4183-80f7-a1baf7c4c7e0]
# 8       [be89a7da-d9fa-49d4-9fdc-388c27a15bc8]
# ...                                        ...
# 217477  [ec0717a6-a3fc-4e38-93f5-481d61967fdf]
# 217478  [444db2d3-2856-4307-8a36-09b15651fb8b]
# 217480  [082ca223-fb94-4eac-a1b4-5be083fa4bf6]
# 217482  [f1721193-a006-419c-848e-85f5269e42bd]
# 217484  [cf753a28-8964-4b3a-a607-b9345d03d88a]
#
#                                        recommendedByModel  \
# 1       [a203c57c-8693-45c8-a4bb-31f73bae4a8d, 1b31e22...
# 2       [a203c57c-8693-45c8-a4bb-31f73bae4a8d, 1b31e22...
# 4       [78fe8ccc-99cf-4da8-88d1-080a13ab6ca4, 870c8a9...
# 7       [78fe8ccc-99cf-4da8-88d1-080a13ab6ca4, bf445aa...
# 8       [78fe8ccc-99cf-4da8-88d1-080a13ab6ca4, 870c8a9...
# ...                                                   ...
# 217477  [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 217478  [bf445aa0-38de-49ca-9c5f-8bb9af9c9849, 0155832...
# 217480  [78fe8ccc-99cf-4da8-88d1-080a13ab6ca4, 870c8a9...
# 217482  [78fe8ccc-99cf-4da8-88d1-080a13ab6ca4, 870c8a9...
# 217484  [bf445aa0-38de-49ca-9c5f-8bb9af9c9849, 24b07fb...
#
#                                      recommendedByRandomW  \
# 1       [1e1b3876-eac3-4aab-aac9-6e9eea85d449, bad3ccf...
# 2       [ae306b4a-0acb-4b3b-b3ce-eaf8bcd5800c, d0f1198...
# 4       [38e587ad-1ccd-41e7-9925-c863da80e7f4, a7aaddb...
# 7       [401ae1cd-ad1d-4929-b815-3e7fa98f55e7, 1b606d6...
# 8       [d0f11985-f883-452e-b817-226d924e5557, ad4b88a...
# ...                                                   ...
# 217477  [964850d4-5df8-4d62-bee9-beb0e677cc5f, 5fb5aa2...
# 217478  [bdf7dde7-1e7c-49b9-8dec-5fbdbd0c859a, a3be043...
# 217480  [167c7437-0115-4cab-98c4-e2f6066b9933, 237df8c...
# 217482  [a382d43f-1e7d-43ff-bf43-8c76bb079c89, 74ec4cc...
# 217484  [691d5e0f-2317-4b42-bc42-6b18dedad90e, b678d8f...
#
#                                      recommendedByPopular  \
# 1       [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 2       [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 4       [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 7       [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 8       [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# ...                                                   ...
# 217477  [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 217478  [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 217480  [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 217482  [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
# 217484  [d2593c3d-2347-40d9-948c-b6065e8459a9, f6b5d17...
#
#                                         recommendedMerged
# 1       [1e1b3876-eac3-4aab-aac9-6e9eea85d449, bad3ccf...
# 2       [ae306b4a-0acb-4b3b-b3ce-eaf8bcd5800c, d0f1198...
# 4       [38e587ad-1ccd-41e7-9925-c863da80e7f4, a7aaddb...
# 7       [401ae1cd-ad1d-4929-b815-3e7fa98f55e7, 1b606d6...
# 8       [d0f11985-f883-452e-b817-226d924e5557, ad4b88a...
# ...                                                   ...
# 217477  [964850d4-5df8-4d62-bee9-beb0e677cc5f, 5fb5aa2...
# 217478  [bdf7dde7-1e7c-49b9-8dec-5fbdbd0c859a, a3be043...
# 217480  [167c7437-0115-4cab-98c4-e2f6066b9933, 237df8c...
# 217482  [a382d43f-1e7d-43ff-bf43-8c76bb079c89, 74ec4cc...
# 217484  [691d5e0f-2317-4b42-bc42-6b18dedad90e, b678d8f...
#
# [108743 rows x 7 columns]

# %% [markdown]
# ### Removing unused columns

# %%
df_valid.drop(columns=["recommendedByModel","recommendedByRandomW","recommendedByPopular"],inplace=True)
df_valid_recommends = df_valid.drop(columns=["userType"])
df_valid_recommends
# Out:
#                                                    userId  \
# 1       00025217b55f104ede326550e7b46c3969a5a5333fcd29...
# 2       0003f534fe8124d98eef78b01baa3b69e3ffcda6e5a657...
# 4       00043e84a871699b666933c3ca7989598879d47b325901...
# 7       0004749749d85d78d13c6c9113130278a18f069f71ccca...
# 8       0004e1ddec9a5d67faa56bb734d733628a7841c10c7255...
# ...                                                   ...
# 217477  fffcb5799256bd50b519b5688f54a6021ca3ef1af66b8b...
# 217478  fffd676b5b33c111de923c2ce93f767f206bf7218d43a6...
# 217480  fffdf305577419378c3be19c54c443fd2744e0f2dc65dc...
# 217482  fffe0be2e6d6f38ae63123c674646bc8e759578305ae97...
# 217484  fffef1890d6f8c974caa19bb8fb46b3b4cb5dc9dc006bc...
#
#                                        history  \
# 1       [d88f5d3a-8657-4955-88fb-71702d92909a]
# 2       [6813846e-9f28-4238-8ea5-4e3436064657]
# 4       [aeab0e46-f1e4-41e9-821b-571255c41f69]
# 7       [487330a8-b48e-4183-80f7-a1baf7c4c7e0]
# 8       [be89a7da-d9fa-49d4-9fdc-388c27a15bc8]
# ...                                        ...
# 217477  [ec0717a6-a3fc-4e38-93f5-481d61967fdf]
# 217478  [444db2d3-2856-4307-8a36-09b15651fb8b]
# 217480  [082ca223-fb94-4eac-a1b4-5be083fa4bf6]
# 217482  [f1721193-a006-419c-848e-85f5269e42bd]
# 217484  [cf753a28-8964-4b3a-a607-b9345d03d88a]
#
#                                         recommendedMerged
# 1       [1e1b3876-eac3-4aab-aac9-6e9eea85d449, bad3ccf...
# 2       [ae306b4a-0acb-4b3b-b3ce-eaf8bcd5800c, d0f1198...
# 4       [38e587ad-1ccd-41e7-9925-c863da80e7f4, a7aaddb...
# 7       [401ae1cd-ad1d-4929-b815-3e7fa98f55e7, 1b606d6...
# 8       [d0f11985-f883-452e-b817-226d924e5557, ad4b88a...
# ...                                                   ...
# 217477  [964850d4-5df8-4d62-bee9-beb0e677cc5f, 5fb5aa2...
# 217478  [bdf7dde7-1e7c-49b9-8dec-5fbdbd0c859a, a3be043...
# 217480  [167c7437-0115-4cab-98c4-e2f6066b9933, 237df8c...
# 217482  [a382d43f-1e7d-43ff-bf43-8c76bb079c89, 74ec4cc...
# 217484  [691d5e0f-2317-4b42-bc42-6b18dedad90e, b678d8f...
#
# [108743 rows x 3 columns]

# %% [markdown]
# ### Retrieve a Compact representation of "df_final_recommends_exploded_top_recent"
# * Further Validation histories & Recommended histories back to list format

# %% [markdown]
# ## Merging Recommendations with Validation Histories

# %%
df_final_recommends = df_valid_recommends
df_final_recommends
# Out:
#                                                    userId  \
# 1       00025217b55f104ede326550e7b46c3969a5a5333fcd29...
# 2       0003f534fe8124d98eef78b01baa3b69e3ffcda6e5a657...
# 4       00043e84a871699b666933c3ca7989598879d47b325901...
# 7       0004749749d85d78d13c6c9113130278a18f069f71ccca...
# 8       0004e1ddec9a5d67faa56bb734d733628a7841c10c7255...
# ...                                                   ...
# 217477  fffcb5799256bd50b519b5688f54a6021ca3ef1af66b8b...
# 217478  fffd676b5b33c111de923c2ce93f767f206bf7218d43a6...
# 217480  fffdf305577419378c3be19c54c443fd2744e0f2dc65dc...
# 217482  fffe0be2e6d6f38ae63123c674646bc8e759578305ae97...
# 217484  fffef1890d6f8c974caa19bb8fb46b3b4cb5dc9dc006bc...
#
#                                        history  \
# 1       [d88f5d3a-8657-4955-88fb-71702d92909a]
# 2       [6813846e-9f28-4238-8ea5-4e3436064657]
# 4       [aeab0e46-f1e4-41e9-821b-571255c41f69]
# 7       [487330a8-b48e-4183-80f7-a1baf7c4c7e0]
# 8       [be89a7da-d9fa-49d4-9fdc-388c27a15bc8]
# ...                                        ...
# 217477  [ec0717a6-a3fc-4e38-93f5-481d61967fdf]
# 217478  [444db2d3-2856-4307-8a36-09b15651fb8b]
# 217480  [082ca223-fb94-4eac-a1b4-5be083fa4bf6]
# 217482  [f1721193-a006-419c-848e-85f5269e42bd]
# 217484  [cf753a28-8964-4b3a-a607-b9345d03d88a]
#
#                                         recommendedMerged
# 1       [1e1b3876-eac3-4aab-aac9-6e9eea85d449, bad3ccf...
# 2       [ae306b4a-0acb-4b3b-b3ce-eaf8bcd5800c, d0f1198...
# 4       [38e587ad-1ccd-41e7-9925-c863da80e7f4, a7aaddb...
# 7       [401ae1cd-ad1d-4929-b815-3e7fa98f55e7, 1b606d6...
# 8       [d0f11985-f883-452e-b817-226d924e5557, ad4b88a...
# ...                                                   ...
# 217477  [964850d4-5df8-4d62-bee9-beb0e677cc5f, 5fb5aa2...
# 217478  [bdf7dde7-1e7c-49b9-8dec-5fbdbd0c859a, a3be043...
# 217480  [167c7437-0115-4cab-98c4-e2f6066b9933, 237df8c...
# 217482  [a382d43f-1e7d-43ff-bf43-8c76bb079c89, 74ec4cc...
# 217484  [691d5e0f-2317-4b42-bc42-6b18dedad90e, b678d8f...
#
# [108743 rows x 3 columns]

# %% [markdown]
# ## CHECK PERFORMANCE FOR THE RECOMMENDATION SYSTEM

# %% [markdown]
# ### Verify intersection between Recommended and Validation Histories
# * Results in a list with all histories' intersection

# %%
df_final_recommends["matched_recommendations"] = df_final_recommends.apply(lambda x :
    list_intersection(x.history, x.recommendedMerged),
    axis=1
)

# %% [markdown]
# ## Count the size of the intersection set
# * How Many recommended histories are within the validation set, for each user?
# Answer below!

# %%
df_final_recommends["count_matches"] = df_final_recommends["matched_recommendations"].apply(lambda x : len(x))

# %%
df_final_recommends[df_final_recommends["count_matches"]>0]#.head(3)
# Out:
#                                                    userId  \
# 54      0011f6794e4e340826a13d1db435696d5129b22cb944f0...
# 185     0035978ac33f75671cbfd6a7eaf5832f2723b4fc1a56a4...
# 256     004cb0601a44726eebba476fa91f124361e8bd654d1c99...
# 1265    0171c172bf55a2a584f9dc429512f4f32a9f0f09800352...
# 1399    019914b354b5a0ce7cdd61eb9e0f5d142b1d0b9f2add97...
# ...                                                   ...
# 214072  fc09950d098eb15feaa57a0425c64e51abf7659cb8e6f3...
# 214368  fc6762abf868a84763adfe829033dd6ecbe3f11e38b0ad...
# 214385  fc6bac54d5019ec79b0a942daf7ce0e1b025cbcf9af967...
# 214719  fccccd6601581316cebb59a46e1a7e6aa0b15b3c073f57...
# 216873  ff3fccc8056c770438798b39b3874b557e6d9edbe6d204...
#
#                                                   history  \
# 54                 [1f32787b-de2b-49be-8c20-ddaeae34cc22]
# 185                [1f32787b-de2b-49be-8c20-ddaeae34cc22]
# 256     [1f32787b-de2b-49be-8c20-ddaeae34cc22, 4c3d47a...
# 1265               [1f32787b-de2b-49be-8c20-ddaeae34cc22]
# 1399               [1f32787b-de2b-49be-8c20-ddaeae34cc22]
# ...                                                   ...
# 214072  [eb23272d-8e6c-479d-b972-eabeb5f6f3dd, ad2c51f...
# 214368  [eb23272d-8e6c-479d-b972-eabeb5f6f3dd, 1f32787...
# 214385             [f0a78e58-ec7e-494c-9462-fbd6446a9a89]
# 214719             [f6b5d170-48b9-4f8e-88d4-c84b6668f3bd]
# 216873  [d262c24d-1d6a-4c9a-97db-a721bd27f9db, f0a78e5...
#
#                                         recommendedMerged  \
# 54      [6b391b65-9988-4d88-8240-029d7e2382d5, f4350c8...
# 185     [0b69b7d3-3b11-4cd8-9306-23572be9a053, 807d5f5...
# 256     [237df8c5-7599-481b-a62a-a3c4c23e0498, bb8c52f...
# 1265    [01bc9330-2841-46e0-a13b-a1fad9a66148, bfcbb60...
# 1399    [c204edf7-5800-49c1-a191-eb29c5b6274c, 4487047...
# ...                                                   ...
# 214072  [b7e17c35-a165-4afc-9057-eab54a9036b0, a91da75...
# 214368  [a7f59860-f675-4397-bd7f-8c8027bb836b, 33eab9d...
# 214385  [a206a392-7d88-4a07-a8df-eab6231fcd09, 4c0672d...
# 214719  [96458fe6-0c7a-48b5-9742-dde25a32bac3, ef5b734...
# 216873  [b1afc0bd-96b3-48ea-94a5-04d04dcbc30e, 1f7f0f6...
#
#                        matched_recommendations  count_matches
# 54      [1f32787b-de2b-49be-8c20-ddaeae34cc22]              1
# 185     [1f32787b-de2b-49be-8c20-ddaeae34cc22]              1
# 256     [1f32787b-de2b-49be-8c20-ddaeae34cc22]              1
# 1265    [1f32787b-de2b-49be-8c20-ddaeae34cc22]              1
# 1399    [1f32787b-de2b-49be-8c20-ddaeae34cc22]              1
# ...                                        ...            ...
# 214072  [1f32787b-de2b-49be-8c20-ddaeae34cc22]              1
# 214368  [1f32787b-de2b-49be-8c20-ddaeae34cc22]              1
# 214385  [f0a78e58-ec7e-494c-9462-fbd6446a9a89]              1
# 214719  [f6b5d170-48b9-4f8e-88d4-c84b6668f3bd]              1
# 216873  [f0a78e58-ec7e-494c-9462-fbd6446a9a89]              1
#
# [475 rows x 5 columns]

# %% [markdown]
# ## Number of Matches
# * How many did we get correct?

# %%
number_of_matches = df_final_recommends["count_matches"].sum()
validation_set_total_size = df_valid["userId"].count()
percentage_of_matches = 100*number_of_matches/validation_set_total_size
print(f"# of matches = {number_of_matches}")
print(f"valid size = {validation_set_total_size}")
print(f"% of matches = {percentage_of_matches}")
# Out:
# # of matches = 476
# valid size = 108743
# % of matches = 0.43772932510598384
